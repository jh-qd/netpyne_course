# %% [markdown]
# <a href="https://colab.research.google.com/github/jh-qd/netpyne_course/blob/main/NetPyNE_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NetPyNE Course

# %% [markdown]
# ## Install Neuron

# %%
# !pip install neuron
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 68.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Install NetPyNE

# %%
# !pip install netpyne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.3/435.3 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 5.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Load NEURON and NetPyNE Pyton packages into this notebook

# %% [markdown]
# This makes their functions and classes available for building and simulating neuron models.

# %%
import neuron

# %%
import netpyne
